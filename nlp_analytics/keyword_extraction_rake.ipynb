# %%
import os
import pandas as pd
import gc

import tensorflow_hub as hub
from scipy.spatial.distance import cdist

# %%
path = 'C:/Users/bill/Documents/projects/data/covid19/open_research/clean_csv/'
clean_comm = pd.read_csv(os.path.join(path, 'clean_comm_use.csv'), nrows=5000)
clean_comm['source'] = 'clean_comm'
#clean_pmc=pd.read_csv(path+"clean_pmc.csv")
#clean_pmc['source']='clean_pmc'
biox = pd.read_csv(os.path.join(path, 'biorxiv_clean.csv'))
biox['source'] = 'biorx'

all_articles=pd.concat([biox, clean_comm])
all_articles.fillna("Unknown", inplace=True)
all_articles.head()

# clean up
del biox, clean_comm
gc.collect()

# load sentence embedding
module_url = 'C:/Users/bill/Documents/projects/data/sents/universal_sentence_encoder_large'
embed = hub.load(module_url)

def get_top_similar(sentence, sentence_list, embed_vectors, top):
    similarity_row = cdist(embed_vectors, embed([sentence]).numpy()[0].reshape(1, -1), 'cosine').reshape(-1)
    results = similarity_row.argsort()
    return [ (results[i], sentence_list[results[i]]) for i in range(top + 1) ]

# find similar sentences
sentence_list = all_articles.title.values.tolist()
embed_vectors = embed(sentence_list).numpy()
sentence = 'Role of the environment in transmission'
similar = get_top_similar(sentence, sentence_list, embed_vectors, 10)
print('similar title to {}'.format(sentence))
for sent in similar:
    print('- {}'.format(sent[1]))
print('\n')
    
# extract title and abstract from similar articles
ind, title = list(map(list, zip(*similar)))
titles = []
texts = []
for i in ind:
    titles.append(all_articles.iloc[i]['title'])
    texts.append(all_articles.iloc[i]['abstract'])
    
import re
def clean(txt):
    txt=re.sub(r'\n','',txt)
    txt=re.sub(r'\([^()]*\)','',txt)
    txt=re.sub(r'https?:\S+\sdoi','',txt)
    return txt

texts = list(map(clean, texts))
text_list = ' '.join(texts)
print('after joining all the similar abstracts:')
print(text_list[1:300] + ' ...')
# Out:
# similar title to Role of the environment in transmission
# - Aerobiology and Its Role in the Transmission of Infectious Diseases
# - Regulatory Role of Small Nucleolar RNAs in Human Diseases
# - Bioaerosols Play a Major Role in the Nasopharyngeal Microbiota Content in Agricultural Environment
# - Environmental Health Outdoor environments and human pathogens in air
# - Transmission of Infectious Diseases En Route to Habitat Hotspots
# - The role of absolute humidity on transmission rates of the COVID-19 outbreak
# - Role of fomites in SARS transmission during the largest hospital outbreak in Hong Kong
# - Microglia Play a Major Role in Direct Viral-Induced Demyelination
# - The role of respiratory viruses in the etiology of bacterial pneumonia An ecological perspective
# - Divergent Roles of Autophagy in Virus Infection
# - Title: Transmission potential of COVID-19 in South Korea
#
#
# after joining all the similar abstracts:
# bstractAerobiology plays a fundamental role in the transmission of infectious diseases. As infectious disease and infection control practitioners continue employing contemporary techniques , the central variables affecting the airborne transmission of pathogens are becoming better known. is paper  ...

# %%
# Reka
import RAKE
import operator

# Reka setup with stopword directory
stop_dir = "C:/Users/bill/Documents/projects/data/covid19/open_research/SmartStoplist.txt"
rake_object = RAKE.Rake(stop_dir)

# Extract keywords
keywords = rake_object.run(text_list)
keywords
# Out:
# [('16s rrna gene high-throughput sequencing', 34.5),
#  ('vivo spinal cord slice culture', 25.0),
#  ('highly conserved cellular degradative pathway', 23.25),
#  ('affect numerous vital cellular processes', 22.75),
#  ('human neurological disease multiple sclerosis', 20.375),
#  ('multivariate analysis showed air samples', 20.035714285714285),
#  ('long-term bioaerosol exposure agents', 19.416666666666664),
#  ('follow upper respiratory viral infection', 18.3030303030303),
#  ('complicate lower respiratory viral infection', 18.3030303030303),
#  ('detailed mechanism-based investigation', 15.5),
#  ('highly contaminated agricultural environments', 14.833333333333334),
#  ('neurotropic mouse hepatitis virus', 14.75),
#  ('non-exposed control group', 14.541666666666666),
#  ('severe acute respiratory syndrome', 14.166666666666666),
#  ('efficient disease control measure', 14.125),
#  ('non-agricultural environment control', 13.875),
#  ('inter-individual contacts occurring', 13.75),
#  ('identify at-risk groups', 13.5),
#  ('altering bacterial community structure', 13.2),
#  ('swine barns bioaerosol biodiversity', 13.066666666666666),
#  ('significantly alter contact patterns', 13.0),
#  ('combined long-range airborne', 12.666666666666666),
#  ('streptococcus pneumoniae review 95 abstractviruses', 11.857142857142858),
#  ('urt bacterial community play', 11.7),
#  ('creating additional artificial hotspots', 11.277777777777779),
#  ('infectious diseases en route', 11.228571428571428),
#  ('major public health concern', 11.0),
#  ('upper respiratory tract', 10.5),
#  ('lower respiratory tract', 10.5),
#  ('host cell processes', 10.0),
#  ('including cellular trafficking', 9.75),
#  ('long-range airborne', 9.666666666666666),
#  ('confirmed cases rapidly increased', 9.666666666666666),
#  ('conspecifics en route', 9.5),
#  ('altering animal movements', 9.5),
#  ('antiviral defense mechanism', 9.5),
#  ('control group suggest', 9.291666666666666),
#  ('exposure assessment purposes', 9.25),
#  ('pro-viral process', 9.166666666666666),
#  ('effective control strategies', 9.125),
#  ('real-world settings', 9.0),
#  ('permanova statistical test', 9.0),
#  ('university college london', 9.0),
#  ('unknown abstractthe epidemic', 9.0),
#  ('reported attack rates', 9.0),
#  ('central nervous system', 9.0),
#  ('antigen presentation  functions', 9.0),
#  ('subsequent axonal loss', 9.0),
#  ('calcium-binding protein', 9.0),
#  ('examine temporal associations', 9.0),
#  ('evolved diverse strategies', 9.0),
#  ('immunity-related functions', 9.0),
#  ('highlight recent reports', 9.0),
#  ('evade lysosomal capture', 9.0),
#  ('gene expression regulation', 8.833333333333334),
#  ('exposure assessment studies', 8.75),
#  ('between-host contacts', 8.75),
#  ('multi-agent model', 8.75),
#  ('respiratory viruses influence', 8.642857142857142),
#  ('respiratory viruses promote', 8.642857142857142),
#  ('non-negligible role', 8.583333333333334),
#  ('central variables affecting', 8.5),
#  ('abstractsmall nucleolar rnas', 8.5),
#  ('independent studies demonstrated', 8.5),
#  ('short regulatory rnas', 8.5),
#  ('previous studies demonstrated', 8.5),
#  ('virus-induced model', 8.5),
#  ('common etiologic agent', 8.5),
#  ('identify potential mechanisms', 8.5),
#  ('simulation epidemiological model', 8.25),
#  ('promote bacterial colonization', 8.2),
#  ('viral co-infection', 8.136363636363637),
#  ('wastewater treatment plants', 8.0),
#  ('wider research community', 8.0),
#  ('ward 8a outbreak', 8.0),
#  ('microglia remain quiescent', 8.0),
#  ('myelin sheath leading', 8.0),
#  ('influenza-related deaths', 8.0),
#  ('obligate intracellular pathogens', 8.0),
#  ('2020in south korea', 8.0),
#  ('covid-19 including 12 deaths', 8.0),
#  ('social distancing measures', 8.0),
#  ('chronic inflammation stage', 7.916666666666666),
#  ('epidemiologically important contacts', 7.75),
#  ('bacterial species residing', 7.7),
#  ('infection risk distributions', 7.636363636363637),
#  ('nasopharyngeal bacterial flora', 7.45),
#  ('secondary bacterial pneumonia', 7.45),
#  ('airborne infectious diseases', 7.395238095238096),
#  ('microglia-specific proteins', 7.333333333333334),
#  ('chronic inflammatory demyelination', 7.333333333333333),
#  ('increase disease transmission', 7.1923076923076925),
#  ('fomite route played', 7.0),
#  ('macrophage/microglia-specific', 6.833333333333334),
#  ('pig workers cluster', 6.5),
#  ('current studies revealed', 6.5),
#  ('hypothetical transmission routes', 6.4423076923076925),
#  ('viruses manipulate autophagy', 6.142857142857142),
#  ('rapidly control', 6.125),
#  ('streptococcus pneumoniae', 6.0),
#  ('cellular morphology', 5.75),
#  ('bacterial community', 5.7),
#  ('public health', 5.666666666666666),
#  ('bioaerosol content', 5.666666666666666),
#  ('airborne route', 5.666666666666666),
#  ('respiratory viruses', 5.642857142857142),
#  ('infection risk', 5.636363636363637),
#  ('viral diseases', 5.595238095238095),
#  ('social groups -', 5.5),
#  ('fungal agents', 5.5),
#  ('swine barns', 5.4),
#  ('virus infection', 5.386363636363637),
#  ('major concern', 5.333333333333334),
#  ('infectious disease', 5.3),
#  ('exposure markers', 5.25),
#  ('combined routes', 5.25),
#  ('air samples', 5.035714285714286),
#  ('artificial stress', 5.0),
#  ('farm environment', 5.0),
#  ('microbial community', 5.0),
#  ('disease propagation', 5.0),
#  ('increased expression', 5.0),
#  ('wide range', 5.0),
#  ('identified individual', 5.0),
#  ('south korea', 5.0),
#  ('co-infection', 4.96969696969697),
#  ('acute inflammation', 4.916666666666666),
#  ('chronic inflammation', 4.916666666666666),
#  ('nasopharyngeal flora', 4.75),
#  ('hypothetical routes', 4.75),
#  ('model selection', 4.75),
#  ('infectious diseases', 4.728571428571428),
#  ('disease transmission', 4.6923076923076925),
#  ('wastewater workers', 4.666666666666666),
#  ('health issue', 4.666666666666666),
#  ('increased carriage', 4.666666666666666),
#  ('coronavirus  infection', 4.636363636363637),
#  ('aerobiological variables', 4.5),
#  ('common origins', 4.5),
#  ('respective measures', 4.5),
#  ('ribosomal rnas', 4.5),
#  ('noncoding rnas', 4.5),
#  ('pig workers', 4.5),
#  ('epidemiological vulnerability', 4.5),
#  ('strongly increase', 4.5),
#  ('outbreak studies', 4.5),
#  ('resident macrophage-', 4.5),
#  ('inhibit colonization', 4.5),
#  ('bacterial pneumonia', 4.45),
#  ('emerging diseases', 4.428571428571429),
#  ('nasopharynx samples', 4.416666666666667),
#  ('swine workers', 4.4),
#  ('human cells', 4.375),
#  ('human pathologies', 4.375),
#  ('human pathogens', 4.375),
#  ('human evolution', 4.375),
#  ('airborne transmission', 4.358974358974359),
#  ('snorna expression', 4.333333333333334),
#  ('outdoor environments', 4.333333333333334),
#  ('co-exist', 4.333333333333334),
#  ('infectious particles', 4.3),
#  ('outdoor air', 4.285714285714286),
#  ('nasopharyngeal region', 4.25),
#  ('nasopharyngeal swabs', 4.25),
#  ('fomite routes', 4.25),
#  ('results suggest', 4.166666666666667),
#  ('viruses exploit', 4.142857142857142),
#  ('mhv infection', 4.136363636363637),
#  ('abstractaerobiology plays', 4.0),
#  ('difficulties controlling', 4.0),
#  ('appreciable players', 4.0),
#  ('canonical function', 4.0),
#  ('posttranscriptional modification', 4.0),
#  ('2 -o-methylation', 4.0),
#  ('alternative splicing', 4.0),
#  ('snorna level', 4.0),
#  ('blood serum', 4.0),
#  ('plasma presents', 4.0),
#  ('promising target', 4.0),
#  ('potent carrier', 4.0),
#  ('study aimed', 4.0),
#  ('low-dust', 4.0),
#  ('microbial link', 4.0),
#  ('germs found', 4.0),
#  ('abstractare pathogens', 4.0),
#  ('research network', 4.0),
#  ('outdoor pathogens', 4.0),
#  ('anticipated challenges', 4.0),
#  ('environmental change', 4.0),
#  ('prevent pathogens', 4.0),
#  ('policy makers', 4.0),
#  ('concise overview', 4.0),
#  ('research aspects', 4.0),
#  ('-places attracting', 4.0),
#  ('large numbers', 4.0),
#  ('wildlife epidemiology', 4.0),
#  ('primarily focused', 4.0),
#  ('exacerbate epidemics', 4.0),
#  ('walsh pd', 4.0),
#  ('meyers la', 4.0),
#  ('significant effect', 4.0),
#  ('global society', 4.0),
#  ('early 2000s', 4.0),
#  ('resurgence exists', 4.0),
#  ('important parameters', 4.0),
#  ('assumed conditions', 4.0),
#  ('perform effector', 4.0),
#  ('persistently infected', 4.0),
#  ('pronounced activation', 4.0),
#  ('membrane ruffling', 4.0),
#  ('experiments performed', 4.0),
#  ('directly infect', 4.0),
#  ('activate microglia', 4.0),
#  ('clinical symptoms', 4.0),
#  ('strong link', 4.0),
#  ('selective autophagy', 4.0),
#  ('incidence data', 4.0),
#  ('air sampling', 3.9523809523809526),
#  ('infectious individuals', 3.9),
#  ('systematic review', 3.857142857142857),
#  ('targeted review', 3.857142857142857),
#  ('review evidence', 3.857142857142857),
#  ('fundamental role', 3.833333333333333),
#  ('substantial role', 3.833333333333333),
#  ('important role', 3.833333333333333),
#  ('pneumococcal pneumonia', 3.75),
#  ('fomite transmission', 3.6923076923076925),
#  ('sustained transmission', 3.6923076923076925),
#  ('territorial animals', 3.666666666666667),
#  ('animals cross', 3.666666666666667),
#  ('results reveal', 3.666666666666667),
#  ('vulnerable individuals', 3.6),
#  ('habitat hotspots', 3.5777777777777775),
#  ('paper reviews', 3.5),
#  ('future techniques', 3.5),
#  ('wildlife populations', 3.5),
#  ('intermediate distances', 3.5),
#  ('sars coronavirus', 3.5),
#  ('nasopharynx sampling', 3.3333333333333335),
#  ('primarily occur', 3.333333333333333),
#  ('/aca snornas', 3.25),
#  ('pneumonia etiology', 3.25),
#  ('reproduction number', 3.2),
#  ('viral', 3.1666666666666665),
#  ('nearest hotspot', 3.142857142857143),
#  ('control', 3.125),
#  ('contacts', 2.75),
#  ('bacterial', 2.7),
#  ('infection', 2.6363636363636362),
#  ('creating', 2.5),
#  ('patterns', 2.5),
#  ('studies', 2.5),
#  ('alter', 2.5),
#  ('treatment', 2.3333333333333335),
#  ('environments', 2.3333333333333335),
#  ('specific', 2.3333333333333335),
#  ('major', 2.3333333333333335),
#  ('air', 2.2857142857142856),
#  ('viruses', 2.142857142857143),
#  ('pathogens', 2.0),
#  ('regulation', 2.0),
#  ('workers', 2.0),
#  ('confirmed', 2.0),
#  ('cluster', 2.0),
#  ('current', 2.0),
#  ('important', 2.0),
#  ('research', 2.0),
#  ('cases', 2.0),
#  ('residing', 2.0),
#  ('potential', 2.0),
#  ('revealed', 2.0),
#  ('fomite', 2.0),
#  ('distributions', 2.0),
#  ('microglia', 2.0),
#  ('leading', 2.0),
#  ('urt', 2.0),
#  ('influenza', 2.0),
#  ('played', 2.0),
#  ('manipulate', 2.0),
#  ('autophagy', 2.0),
#  ('261 cases', 2.0),
#  ('covid-19', 2.0),
#  ('outbreak', 2.0),
#  ('review', 1.8571428571428572),
#  ('role', 1.8333333333333333),
#  ('habitat', 1.8),
#  ('hotspots', 1.7777777777777777),
#  ('pneumonia', 1.75),
#  ('transmission', 1.6923076923076923),
#  ('sampling', 1.6666666666666667),
#  ('results', 1.6666666666666667),
#  ('nasopharynx', 1.6666666666666667),
#  ('animals', 1.6666666666666667),
#  ('demyelination', 1.6666666666666667),
#  ('individuals', 1.6),
#  ('future', 1.5),
#  ('paper', 1.5),
#  ('intermediate', 1.5),
#  ('sars', 1.5),
#  ('populations', 1.5),
#  ('mhv', 1.5),
#  ('etiology', 1.5),
#  ('occur', 1.3333333333333333),
#  ('snornas', 1.25),
#  ('number', 1.2),
#  ('hotspot', 1.1428571428571428),
#  ('detailing', 1.0),
#  ('industries', 1.0),
#  ('undertaking', 1.0),
#  ('effort', 1.0),
#  ('ameliorate', 1.0),
#  ('box', 1.0),
#  ('pseudouridylation', 1.0),
#  ('series', 1.0),
#  ('serve', 1.0),
#  ('source', 1.0),
#  ('fragments', 1.0),
#  ('participate', 1.0),
#  ('mrna', 1.0),
#  ('alterations', 1.0),
#  ('diagnostics', 1.0),
#  ('discuss', 1.0),
#  ('relation', 1.0),
#  ('oncological', 1.0),
#  ('neurodegenerative', 1.0),
#  ('describe', 1.0),
#  ('response', 1.0),
#  ('drugs', 1.0),
#  ('abstractbackground', 1.0),
#  ('bioaerosols', 1.0),
#  ('challenging', 1.0),
#  ('evaluate', 1.0),
#  ('correlation', 1.0),
#  ('methods', 1.0),
#  ('sequenced', 1.0),
#  ('industrial', 1.0),
#  ('validate', 1.0),
#  ('nasopharynxes', 1.0),
#  ('compared', 1.0),
#  ('significance', 1.0),
#  ('unlike', 1.0),
#  ('difference', 1.0),
#  ('carriers', 1.0),
#  ('conclusion', 1.0),
#  ('microbiota', 1.0),
#  ('proxy', 1.0),
#  ('determination', 1.0),
#  ('present', 1.0),
#  ('problem', 1.0),
#  ('set', 1.0),
#  ('uk', 1.0),
#  ('aim', 1.0),
#  ('opening', 1.0),
#  ('discussion', 1.0),
#  ('investigate', 1.0),
#  ('science', 1.0),
#  ('impacts', 1.0),
#  ('objective', 1.0),
#  ('areas', 1.0),
#  ('developing', 1.0),
#  ('activities', 1.0),
#  ('prepare', 1.0),
#  ('work', 1.0),
#  ('benefit', 1.0),
#  ('providing', 1.0),
#  ('considerations', 1.0),
#  ('spread', 1.0),
#  ('influenced', 1.0),
#  ('importance', 1.0),
#  ('territories', 1.0),
#  ('phenomenon', 1.0),
#  ('received', 1.0),
#  ('attention', 1.0),
#  ('case', 1.0),
#  ('visiting', 1.0),
#  ('travel', 1.0),
#  ('developed', 1.0),
#  ('scenario', 1.0),
#  ('find', 1.0),
#  ('nearby', 1.0),
#  ('population', 1.0),
#  ('highest', 1.0),
#  ('vicinity', 1.0),
#  ('interestingly', 1.0),
#  ('visit', 1.0),
#  ('reducing', 1.0),
#  ('citation', 1.0),
#  ('benavides', 1.0),
#  ('raymond', 1.0),
#  ('caillaud', 1.0),
#  ('plos', 1.0),
#  ('e31290', 1.0),
#  ('modes', 1.0),
#  ('limited', 1.0),
#  ('develop', 1.0),
#  ('conducted', 1.0),
#  ('explored', 1.0),
#  ('well-', 1.0),
#  ('considered', 1.0),
#  ('744 scenarios', 1.0),
#  ('combinations', 1.0),
#  ('predict', 1.0),
#  ('carried', 1.0),
#  ('scenarios', 1.0),
#  ('compare', 1.0),
#  ('select', 1.0),
#  ('hypotheses', 1.0),
#  ('fitness', 1.0),
#  ('abstractmicroglia', 1.0),
#  ('unable', 1.0),
#  ('activated', 1.0),
#  ('injury', 1.0),
#  ('suggested', 1.0),
#  ('represent', 1.0),
#  ('line', 1.0),
#  ('defence', 1.0),
#  ('cns', 1.0),
#  ('meningoencephalitis', 1.0),
#  ('myelitis', 1.0),
#  ('evidenced', 1.0),
#  ('characteristic', 1.0),
#  ('iba1', 1.0),
#  ('involved', 1.0),
#  ('phagocytosis', 1.0),
#  ('turn', 1.0),
#  ('abstractpneumonia', 1.0),
#  ('death', 1.0),
#  ('children', 1.0),
#  ('5 years', 1.0),
#  ('worldwide', 1.0),
#  ('severity', 1.0),
#  ('literature', 1.0),
#  ('bacteria', 1.0),
#  ('interactions', 1.0),
#  ('conclude', 1.0),
#  ('lrt', 1.0),
#  ('uncertain', 1.0),
#  ('exception', 1.0),
#  ('established', 1.0),
#  ('ecology', 1.0),
#  ('hosts', 1.0),
#  ('metabolism', 1.0),
#  ('survival', 1.0),
#  ('article', 1.0),
#  ('serves', 1.0),
#  ('alternatively', 1.0),
#  ('degradation', 1.0),
#  ('abstractsince', 1.0),
#  ('jan 20', 1.0),
#  ('feb 26', 1.0),
#  ('estimate', 1.0),
#  ('support', 1.0),
#  ('implementation', 1.0),
#  ('\ue062', 0),
#  ('/', 0),
#  ('2007', 0),
#  ('7', 0),
#  ('1', 0),
#  ('2019', 0),
#  ('2020', 0),
#  ('5', 0)]

# %%
for (word, score) in (keywords[:10]):
    print(int(score), word)
# Out:
# 34 16s rrna gene high-throughput sequencing
# 25 vivo spinal cord slice culture
# 23 highly conserved cellular degradative pathway
# 22 affect numerous vital cellular processes
# 20 human neurological disease multiple sclerosis
# 20 multivariate analysis showed air samples
# 19 long-term bioaerosol exposure agents
# 18 follow upper respiratory viral infection
# 18 complicate lower respiratory viral infection
# 15 detailed mechanism-based investigation
